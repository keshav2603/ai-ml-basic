# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("50_Startups.csv")
df.drop(columns=["State"],inplace=True)
df= round(df/100)

# %%
df.sample(5)
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 19      864.0          1535.0              0.0  1228.0
# 18      917.0          1142.0           2949.0  1243.0
# 37      441.0           513.0           1970.0   899.0
# 43      155.0          1274.0            355.0   698.0
# 9      1233.0          1087.0           3050.0  1498.0

# %%
df=df.sample(3)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 48        5.0           517.0              0.0   357.0
# 12      939.0          1273.0           2498.0  1416.0
# 39      386.0           830.0           1750.0   810.0

# %%
df["f0(x)"]=df["Profit"].mean()

# %%
df["ri1"] = df["Profit"] - df["f0(x)"]

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit  f0(x)    ri1
# 48        5.0           517.0              0.0   357.0  861.0 -504.0
# 12      939.0          1273.0           2498.0  1416.0  861.0  555.0
# 39      386.0           830.0           1750.0   810.0  861.0  -51.0

# %%
from sklearn.tree import DecisionTreeRegressor
dt1=DecisionTreeRegressor(max_depth=1)

# %%
dt1.fit(df.iloc[0:3].values, df["ri1"].values)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[2] <= 2124.0\nsquared_error = 188214.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.25, 0.25, 'squared_error = 51302.25\nsamples = 2\nvalue = -277.5'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 555.0'),
#  Text(0.625, 0.5, '  False')]
