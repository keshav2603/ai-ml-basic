# %%
print("hello")
# Out:
# hello

# %%
import sys
print("python:", sys.version)
# Out:
# python: 3.13.4 (main, Jun  3 2025, 15:34:24) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
import platform
print(platform.python_implementation())
print(platform.platform())
print(sys.executable)
# Out:
# CPython
# macOS-15.6-arm64-arm-64bit-Mach-O
# /Users/keshavmacbook/Projects/AI-ML/AI-ML basic/.aiml-venv/bin/python

# %%
x=10
y=20
x+y
# Out:
# 30
