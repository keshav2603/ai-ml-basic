# %%
print("hello world")
# Out:
# hello world

# %%
class Student:
    # name="keshu"
    def __init__(self,name):
        self.name=name
        print(self)
        print("adding new student in database")

# %%
s1=Student("keshav")
print(s1.name)
# Out:
# ...
# adding new student in database
# keshav

# %%
a,b=list(map(int,input().split()))
print(a)
print(b)
# Out:
# 1
# 2

# %%
s=int(input())
total=0
current_level_point=1
stage=1
for i in range(s):
    if stage==5:
        current_level_point=1
        stage=1
    total+=current_level_point
    current_level_point*=2
    stage+=1
print(total)
# Out:
# 18
