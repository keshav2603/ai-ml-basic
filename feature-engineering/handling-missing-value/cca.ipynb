# %% [markdown]
# # CCA complete Case Analysis

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("data_science_job.csv")
df.sample(10)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 3050         21769  city_118                   0.722  Female
# 2477          4359   city_64                   0.666     NaN
# 2144         10937  city_103                   0.920    Male
# 8817         27826  city_115                   0.789     NaN
# 10979        30085  city_160                   0.920    Male
# 16291        15754   city_28                   0.939    Male
# 13091        13136  city_103                   0.920     NaN
# 7947         20030  city_114                   0.926     NaN
# 5919         13005  city_103                   0.920    Male
# 9498         26023   city_16                   0.910     NaN
#
#            relevent_experience enrolled_university education_level  \
# 3050   Has relevent experience       no_enrollment         Masters
# 2477   Has relevent experience       no_enrollment        Graduate
# 2144   Has relevent experience       no_enrollment        Graduate
# 8817   Has relevent experience       no_enrollment        Graduate
# 10979  Has relevent experience       no_enrollment        Graduate
# 16291   No relevent experience       no_enrollment     High School
# 13091   No relevent experience    Full time course        Graduate
# 7947   Has relevent experience       no_enrollment        Graduate
# 5919   Has relevent experience       no_enrollment        Graduate
# 9498   Has relevent experience       no_enrollment     High School
#
#       major_discipline  experience company_size    company_type  \
# 3050              STEM        20.0          <10         Pvt Ltd
# 2477              STEM        20.0        10/49           Other
# 2144              STEM        20.0    1000-4999   Public Sector
# 8817              STEM         9.0       10000+         Pvt Ltd
# 10979             STEM        16.0      100-500         Pvt Ltd
# 16291              NaN         1.0        50-99   Public Sector
# 13091              NaN         2.0          NaN             NaN
# 7947              STEM        13.0      100-500         Pvt Ltd
# 5919              STEM         9.0    1000-4999         Pvt Ltd
# 9498               NaN        10.0          <10  Funded Startup
#
#        training_hours  target
# 3050             70.0     1.0
# 2477             13.0     0.0
# 2144             33.0     0.0
# 8817             36.0     0.0
# 10979            70.0     0.0
# 16291            99.0     0.0
# 13091           202.0     1.0
# 7947             48.0     0.0
# 5919             28.0     0.0
# 9498             94.0     0.0

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols=[ var for var in df.columns  if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.8968577095730244

# %%
new_df= df[cols].dropna()

# %%
new_df.hist(bins=50,density=True,figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'city_development_index'}>,
#         <Axes: title={'center': 'experience'}>],
#        [<Axes: title={'center': 'training_hours'}>, <Axes: >]],
#       dtype=object)

# %%
temp = pd.concat([
    df["education_level"].value_counts()/len(df),
    new_df["education_level"].value_counts()/len(new_df)
],axis=1)
temp.columns=["original","cca"]

temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.619835
# Masters          0.227633  0.234082
# High School      0.105282  0.107380
# Phd              0.021610  0.022116
# Primary School   0.016077  0.016587
