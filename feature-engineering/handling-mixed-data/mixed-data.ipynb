# %% [markdown]
# # Handeling Mixed Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic.csv")
df.sample(10)
# Out:
#     Cabin    Ticket number  Survived
# 649   NaN  CA. 2314      5         1
# 272   NaN    250644      1         1
# 552   NaN    330979      6         0
# 532   NaN      2690      5         0
# 737  B101  PC 17755      5         1
# 708   NaN    113781      4         1
# 483   NaN      4134      4         1
# 177   C49  PC 17595      6         0
# 397   NaN     28403      2         0
# 46    NaN    370371      3         0

# %%
df["number"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='number'>

# %%
df["number_num"]=pd.to_numeric(df["number"],errors="coerce",downcast="integer")

# %%
df["number_cat"]=np.where(df["number_num"].isnull(),df["number"],np.nan)

# %%
df.sample(10)
# Out:
#      Cabin      Ticket number  Survived  number_num number_cat
# 70     NaN  C.A. 33111      1         0         1.0        NaN
# 186    NaN      370365      6         1         6.0        NaN
# 642    NaN      347088      A         0         NaN          A
# 618     F4      230136      4         1         4.0        NaN
# 496    D20       36947      A         1         NaN          A
# 179    NaN        LINE      1         0         1.0        NaN
# 746    NaN   C.A. 2673      1         0         1.0        NaN
# 699  F G63      348121      A         0         NaN          A
# 212    NaN   A/5 21174      A         0         NaN          A
# 881    NaN      349257      A         0         NaN          A

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df["cabin_num"]=df["Cabin"].str.extract("(\d+)")
df["cabin_cat"]=df["Cabin"].str[0]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/x4/dcd672b95h70g_8b6vm4lcp40000gn/T/ipykernel_11189/3496482295.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df["cabin_num"]=df["Cabin"].str.extract("(\d+)")

# %%
df.sample(10)
# Out:
#     Cabin           Ticket number  Survived  number_num number_cat cabin_num  \
# 74    NaN             1601      6         1         6.0        NaN       NaN
# 846   NaN         CA. 2343      3         0         3.0        NaN       NaN
# 847   NaN           349213      2         0         2.0        NaN       NaN
# 157   NaN  SOTON/OQ 392090      1         0         1.0        NaN       NaN
# 650   NaN           349221      5         0         5.0        NaN       NaN
# 404   NaN           315096      A         0         NaN          A       NaN
# 37    NaN       A./5. 2152      6         0         6.0        NaN       NaN
# 463   NaN           234360      5         0         5.0        NaN       NaN
# 85    NaN          3101278      5         1         5.0        NaN       NaN
# 290   NaN            19877      3         1         3.0        NaN       NaN
#
#     cabin_cat
# 74        NaN
# 846       NaN
# 847       NaN
# 157       NaN
# 650       NaN
# 404       NaN
# ...

# %%
df["ticket_num"]=df["Ticket"].apply(lambda x: x.split()[-1] )
df["ticket_num"]=pd.to_numeric(df["ticket_num"],errors="coerce",downcast="integer")

# %%
df["ticekt_cat"]=df["Ticket"].apply(lambda x: x.split()[0])
df["ticekt_cat"] = np.where(df["ticekt_cat"].str.isdigit(),np.nan,df["ticekt_cat"])

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_num number_cat cabin_num  \
# 0     NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1     C85          PC 17599      3         1         3.0        NaN        85
# 2     NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3    C123            113803      3         1         3.0        NaN       123
# 4     NaN            373450      A         0         NaN          A       NaN
# ..    ...               ...    ...       ...         ...        ...       ...
# 886   NaN            211536      3         0         3.0        NaN       NaN
# 887   B42            112053      3         1         3.0        NaN        42
# 888   NaN        W./C. 6607      1         0         1.0        NaN       NaN
# 889  C148            111369      2         1         2.0        NaN       148
# 890   NaN            370376      3         0         3.0        NaN       NaN
#
# ...
