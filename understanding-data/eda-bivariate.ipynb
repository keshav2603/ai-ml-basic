# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # EDA USING BIVARIATE ANALYSIS

# %%
import pandas as pd
import seaborn as sns

# %%
tips= sns.load_dataset("tips")
titanic = pd.read_csv("train.csv")
flights = sns.load_dataset('flights')
iris = sns.load_dataset("iris")

# %% [markdown]
# ### numerical -numerical

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x="total_bill",y="tip",hue="sex",style="smoker",size="size",kind="scatter")

# %% [markdown]
# # numerical - categorical

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 381          382         1       3
# 623          624         0       3
# 398          399         0       2
# 619          620         0       2
# 377          378         0       1
# 752          753         0       3
# 356          357         1       1
# 240          241         0       3
# 526          527         1       2
# 567          568         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 381                  Nakid, Miss. Maria ("Mary")  female   1.0      0      2
# 623                  Hansen, Mr. Henry Damsgaard    male  21.0      0      0
# 398                             Pain, Dr. Alfred    male  23.0      0      0
# 619                          Gavey, Mr. Lawrence    male  26.0      0      0
# 377                    Widener, Mr. Harry Elkins    male  27.0      0      2
# 752             Vande Velde, Mr. Johannes Joseph    male  33.0      0      0
# ...

# %%
sns.catplot(kind="bar",data=titanic,x="Pclass",y="Age",hue="Sex")

# %%
sns.boxplot(data=titanic,x="Sex",y="Age",hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.displot(data=titanic,x="Age",kind="kde",hue="Survived")

# sns.distplot(titanic["Age"])

# %% [markdown]
# # categorical - categorical

# %%
sns.heatmap(pd.crosstab(titanic["Pclass"],titanic["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby(["Embarked","Pclass"])["Survived"].sum()
# Out:
# Embarked  Pclass
# C         1         59
#           2          9
#           3         25
# Q         1          1
#           2          2
#           3         27
# S         1         74
#           2         76
#           3         67
# Name: Survived, dtype: int64

# %%
sns.pairplot(iris,hue="species")
